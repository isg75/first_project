# %%
#Load first dataset
import pandas as pd

pt1_df = pd.read_csv("../data/raw/df_final_web_data_pt_1.txt")
pt1_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# 343137    2443347  465784886_73090545671  136329900_10529659391_316129
# 343138    2443347  465784886_73090545671  136329900_10529659391_316129
# 343139    2443347  465784886_73090545671  136329900_10529659391_316129
# 343140    2443347  465784886_73090545671  136329900_10529659391_316129
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
#Load second dataset
pt2_df = pd.read_csv("../data/raw/df_final_web_data_pt_2.txt") 
pt2_df
# Out:
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0           confirm  2017-06-06 08:56:00
# ...

# %%
#We merge these two dataframes prior to a comprehensive data analysis.
#Display the first "n" rows of the dataset
digital_footprints = pd.concat([pt1_df, pt2_df], ignore_index=True)
digital_footprints.head(20)
# Out:
#     client_id             visitor_id                      visit_id  \
# 0     9988021   580560515_7732621733  781255054_21935453173_531117
# 1     9988021   580560515_7732621733  781255054_21935453173_531117
# 2     9988021   580560515_7732621733  781255054_21935453173_531117
# 3     9988021   580560515_7732621733  781255054_21935453173_531117
# 4     9988021   580560515_7732621733  781255054_21935453173_531117
# 5     9988021   580560515_7732621733  781255054_21935453173_531117
# 6     9988021   580560515_7732621733  781255054_21935453173_531117
# 7     9988021   580560515_7732621733  781255054_21935453173_531117
# 8     8320017   39393514_33118319366  960651974_70596002104_312201
# 9     8320017   39393514_33118319366  960651974_70596002104_312201
# 10    8320017   39393514_33118319366  960651974_70596002104_312201
# 11    8320017   39393514_33118319366  960651974_70596002104_312201
# 12    8320017   39393514_33118319366  960651974_70596002104_312201
# ...

# %%
#Retrievethe number of rows and columns in the dataframe
digital_footprints.shape
# Out:
# (755405, 5)

# %%
#Display the data types of each column in the dataframe
digital_footprints.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
#Retrieve the unique data types present in the dataframe columns
list(set(digital_footprints.dtypes.tolist()))
# Out:
# [dtype('int64'), dtype('O')]

# %%
#Extract column names with numerical data types from the dataframe
digital_footprints.select_dtypes("number").columns
# Out:
# Index(['client_id'], dtype='object')

# %%
#Count and sort the unique values for each numerical column in descending order
digital_footprints.select_dtypes("number").nunique().sort_values(ascending=False)
# Out:
# client_id    120157
# dtype: int64

# %%
#Checking for missing values and blank spaces (ROWS)
blank_rows = digital_footprints[digital_footprints['process_step'].isnull() | (digital_footprints['process_step'].str.strip() == '')]
print(blank_rows)
# Out:
# Empty DataFrame
# Columns: [client_id, visitor_id, visit_id, process_step, date_time]
# Index: []

# %%
#Checking missing values (COLUMNS)
digital_footprints.columns = digital_footprints.columns.str.strip()
print(digital_footprints.columns)
# Out:
# Index(['client_id', 'visitor_id', 'visit_id', 'process_step', 'date_time'], dtype='object')

# %%
#Check missing values of the whole dataframe
digital_footprints.isnull().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
#Convert date_time column to datetime type
digital_footprints['date_time'] = pd.to_datetime(digital_footprints['date_time'])
digital_footprints.dtypes
# Out:
# client_id                int64
# visitor_id              object
# visit_id                object
# process_step            object
# date_time       datetime64[ns]
# dtype: object

# %%
digital_footprints.to_csv('digital_footprints_cleaned.csv', index=False)
